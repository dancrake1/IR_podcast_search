# %%
import pandas as pd
import requests
import re
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
metadata = pd.read_csv('metadata.tsv', sep = '\t')

# %%
metadf = metadata.loc[:,['episode_uri','show_name', 'show_description', 'episode_name', 'episode_description']]

# %%
# generate docno column and convert all to strings for PyTerrier compatibility
metadf['docno'] = metadf.index
metadf = metadf.astype(str)
metadf.head()
# Out:
#                               episode_uri  \
# 0  spotify:episode:000A9sRBYdVh66csG2qEdj
# 1  spotify:episode:000HP8n3hNIfglT2wSI2cA
# 2  spotify:episode:001UfOruzkA3Bn1SPjcdfa
# 3  spotify:episode:001i89SvIQgDuuyC53hfBm
# 4  spotify:episode:0025RWNwe2lnp6HcnfzwzG
#
#                                            show_name  \
# 0                               Kream in your Koffee
# 1                              Morning Cup Of Murder
# 2  Inside The 18 : A Podcast for Goalkeepers by G...
# 3                                    Arrowhead Live!
# 4                                              FBoL
#
#                                     show_description  \
# 0  A 20-something blunt female takes on the world...
# 1  Ever wonder what murder took place on today in...
# 2  Inside the 18 is your source for all things Go...
# 3  Your favorite podcast for everything @Chiefs! ...
# 4  The comedy podcast about toxic characters, wri...
#
#                                         episode_name  \
# 0                            1: It’s Christmas Time!
# 1  The Goleta Postal Facility shootings- January ...
# 2  Ep.36 - Incorporating a Singular Goalkeeping C...
# 3                   Episode 1: Arrowhead Live! Debut
# 4  The Lion, The Witch, And The Wardrobe - Ashley...
#
#                                  episode_description docno
# 0  On the first ever episode of Kream in your Kof...     0
# 1  See something, say something. It’s a mantra ma...     1
# 2  Today’s episode is a sit down Michael and Omar...     2
# 3  Join us as we take a look at all current Chief...     3
# 4  The modern morality tail of how to stay good f...     4

# %%
# example metadata for presentation
metadf[['show_name', 'episode_name', 'episode_description']]
# Out:
#                                                 show_name  \
# 0                                    Kream in your Koffee
# 1                                   Morning Cup Of Murder
# 2       Inside The 18 : A Podcast for Goalkeepers by G...
# 3                                         Arrowhead Live!
# 4                                                   FBoL
# ...                                                   ...
# 105355                                         The Top 10
# 105356                          Let's Grab Coffee Podcast
# 105357                                  Coach Corey Wayne
# 105358                                The Cricket Podcast
# 105359           Sleepyhead Stories - Mother/Daughter Duo
#
#                                              episode_name  \
# 0                                 1: It’s Christmas Time!
# 1       The Goleta Postal Facility shootings- January ...
# 2       Ep.36 - Incorporating a Singular Goalkeeping C...
# 3                        Episode 1: Arrowhead Live! Debut
# 4       The Lion, The Witch, And The Wardrobe - Ashley...
# ...                                                   ...
# 105355          The Top 10 - Re-List - Steve Martin Moves
# 105356  Let's Grab Coffee E45 with Ross Paquette | Gro...
# 105357                      Maybe She Is Just Testing Me?
# 105358                           Ep 16: England In Danger
# 105359         The Tale Of Little Pig Robinson 🐖 (part 2)
#
#                                       episode_description
# 0       On the first ever episode of Kream in your Kof...
# 1       See something, say something. It’s a mantra ma...
# 2       Today’s episode is a sit down Michael and Omar...
# 3       Join us as we take a look at all current Chief...
# 4       The modern morality tail of how to stay good f...
# ...                                                   ...
# 105355  Thanks to our patreon members for their suppor...
# 105356  Ross founded Maropost in 2011 as a customer-ce...
# 105357  How to know if your woman is maybe just testin...
# 105358  In Episode 16, the boys evaluate England's per...
# 105359  Little Pig Robinson finally makes it to the ma...
#
# [105360 rows x 3 columns]

# %% [markdown]
# <div style="background-color: #090e60; padding: 10px; border: 8px solid  white;">
#     <p style="text-align: center; font-weight: bold; color: white; font-size: 30px; margin: 0; position: relative; top: 50%; transform: translateY(-50%); font-family: 'Italianno', cursive;">&ndash;&ndash;&ndash;&nbsp;Queries&nbsp;&ndash;&ndash;&ndash;
#     </p>
# </div>

# %%
urls = [
    "https://trecpodcasts.github.io/resources/podcasts_2020_topics_train.xml",
    "https://trecpodcasts.github.io/resources/podcasts_2020_topics_test.xml"
]

tables = []
for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "xml")
    rows = soup.find_all("topic")

    # Create dict with column headings and empty lists
    table_dict = {"num": [], "query": [], "type": [], "description": []}

    # For every row in the table, find each cell element and add it to the list
    for row in rows:
        table_dict = {
            col: table_dict[col] + [row.find(col).text] for col in table_dict
        }

    table = pd.DataFrame(table_dict)
    table = table.applymap(lambda x: x[0] if isinstance(x, list) else x)
    tables.append(table)

query = pd.concat(tables, ignore_index=True)
query.head()
# Out:
#   num                          query        type  \
# 0   1             coronavirus spread     topical
# 1   2  greta thunberg cross atlantic     topical
# 2   3               black hole image     topical
# 3   4      story about riding a bird   refinding
# 4   5            daniel ek interview  known item
#
#                                          description
# 0  What were people saying about the spread of th...
# 1  What were people saying about Greta Thunberg’s...
# 2  In May 2019 astronomers released the first-eve...
# 3  I remember hearing a podcast that had a story ...
# 4  Someone told me about a podcast interview with...

# %%
query = query[~query['num'].isin(['47', '50'])].reset_index(drop=True)
query.head()
# Out:
#   num                          query        type  \
# 0   1             coronavirus spread     topical
# 1   2  greta thunberg cross atlantic     topical
# 2   3               black hole image     topical
# 3   4      story about riding a bird   refinding
# 4   5            daniel ek interview  known item
#
#                                          description
# 0  What were people saying about the spread of th...
# 1  What were people saying about Greta Thunberg’s...
# 2  In May 2019 astronomers released the first-eve...
# 3  I remember hearing a podcast that had a story ...
# 4  Someone told me about a podcast interview with...

# %%
pd.options.display.max_colwidth = 200
short_query = query.loc[:, ['num', 'query']].rename(columns={'num': 'qid','query': 'query'})
full_query = query.loc[:, ['num', 'description']].rename(columns={'num': 'qid','description': 'query'})

# %%
def remove_non_alphanumeric(row):
  return re.sub(r'[^a-zA-Z0-9 ]+', '', row.query)

full_query['query'] = full_query.apply(remove_non_alphanumeric, axis=1)
full_query.head()
# Out:
#   qid  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                                                                                                                      query
# 0                                                                                                     What were people saying about the spread of the novel coronavirus NCOV19 in Wuhan at the end of 2019
# 1                                                   What were people saying about Greta Thunbergs sailing trip across the Atlantic Ocean in the fall of 2019 and its relationship to global climate change
# 2  In May 2019 astronomers released the firstever picture of a black hole I would like to hear some conversations and educational discussion about the science of astronomy black holes and of the pict...
# 3                                                                                               I remember hearing a podcast that had a story about a kid riding some kind of bird I want to find it again
# 4  Someone told me about a podcast interview with Daniel Ek CEO of Spotify about the founding and early days of Spotify I would like to find the show and episode that contains that interview Other in...

# %% [markdown]
# <div style="background-color: #090e60; padding: 10px; border: 8px solid  white;">
#     <p style="text-align: center; font-weight: bold; color: white; font-size: 30px; margin: 0; position: relative; top: 50%; transform: translateY(-50%); font-family: 'Italianno', cursive;">&ndash;&ndash;&ndash;&nbsp;Qrels&nbsp;&ndash;&ndash;&ndash;
#     </p>
# </div>

# %%
url_train = "https://trecpodcasts.github.io/resources/2020_train_qrels.list"
url_test ="https://trecpodcasts.github.io/resources/2020_test_qrels.list"

# %%
response = requests.get(url_train)
lines = response.text.split("\n")

data = []
for line in lines:
    if line:
        query, _, episode_uri, relevance = line.split("\t")
        data.append({"query": query, "episode_uri": episode_uri, "relevance": relevance})

qrel = pd.DataFrame(data)
pd.options.display.max_colwidth = 50
print(qrel.shape)
qrel
# Out:
# (609, 3)
#     query                                    episode_uri relevance
# 0       1   spotify:episode:0E2nqCXMkS218SE72APmNr_240.0         2
# 1       1   spotify:episode:0E2nqCXMkS218SE72APmNr_300.0         2
# 2       1   spotify:episode:0E2nqCXMkS218SE72APmNr_360.0         2
# 3       1   spotify:episode:0Th494DvnO5dU8vTi3QHm2_120.0         1
# 4       1  spotify:episode:199bOiXL0l4YsRaSNDNXvP_1200.0         2
# ..    ...                                            ...       ...
# 604     8   spotify:episode:7MnlmF9PV3WUOPI8IjGd0y_720.0         0
# 605     8   spotify:episode:7MnlmF9PV3WUOPI8IjGd0y_780.0         0
# 606     8   spotify:episode:7wJUUYWcHm7YwEoCmTGFoD_240.0         1
# 607     8   spotify:episode:7wJUUYWcHm7YwEoCmTGFoD_300.0         1
# 608     8   spotify:episode:7yzpqVjoQqFh5k9W7esm29_360.0         0
#
# [609 rows x 3 columns]

# %%
# add Podcast Track 2020 test set QRels
url_test = "https://trecpodcasts.github.io/resources/2020_test_qrels.list"
response_test = requests.get(url_test)

lines_test = response_test.text.split("\n")
data_test = []
for line in lines_test:
    if line:
        query, _, episode_uri, relevance = line.split()
        data_test.append({"query": query, "episode_uri": episode_uri, "relevance": relevance})

qrel_test = pd.DataFrame(data_test)
qrel = qrel.append(qrel_test).reset_index(drop=True)
print(qrel.shape)
qrel
# Out:
# (10035, 3)
# <ipython-input-120-eefbea306c5a>:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   qrel = qrel.append(qrel_test).reset_index(drop=True)
#       query                                    episode_uri relevance
# 0         1   spotify:episode:0E2nqCXMkS218SE72APmNr_240.0         2
# 1         1   spotify:episode:0E2nqCXMkS218SE72APmNr_300.0         2
# 2         1   spotify:episode:0E2nqCXMkS218SE72APmNr_360.0         2
# 3         1   spotify:episode:0Th494DvnO5dU8vTi3QHm2_120.0         1
# 4         1  spotify:episode:199bOiXL0l4YsRaSNDNXvP_1200.0         2
# ...     ...                                            ...       ...
# 10030    32   spotify:episode:7lrWzeepJQwhr0jyuVEk9m_300.0         0
# 10031    32   spotify:episode:7lrWzeepJQwhr0jyuVEk9m_600.0         0
# 10032    32   spotify:episode:7ok6wB1WviyXvxba0wdb5q_720.0         0
# 10033    32   spotify:episode:7ok6wB1WviyXvxba0wdb5q_780.0         0
# 10034    32   spotify:episode:7pRpADlrOriqKmWPR6CD3v_420.0         0
#
# [10035 rows x 3 columns]

# %%
qrel['episode_uri'] = qrel['episode_uri'].apply(lambda uri: uri.split('_')[0])
qrel = qrel.groupby(['query', 'episode_uri']).max().reset_index()
qrel
# Out:
#      query                             episode_uri relevance
# 0        1  spotify:episode:0E2nqCXMkS218SE72APmNr         2
# 1        1  spotify:episode:0Th494DvnO5dU8vTi3QHm2         1
# 2        1  spotify:episode:199bOiXL0l4YsRaSNDNXvP         2
# 3        1  spotify:episode:1ZA1QTtylexrVt75xiprNH         2
# 4        1  spotify:episode:1o0HCHjNtRWdEWRTWJhzyC         0
# ...    ...                                     ...       ...
# 5825     9  spotify:episode:6v0auT8BbeXzMTmg9FjyDB         1
# 5826     9  spotify:episode:7EKJswck8jP4tXWHXVJCdO         0
# 5827     9  spotify:episode:7N0z3FpvsWWTCSgARuCd8C         0
# 5828     9  spotify:episode:7mIga7ujiMVbbEN5bBQPUX         0
# 5829     9  spotify:episode:7mh26AlQ7FEKg9Gj0Eq2mz         0
#
# [5830 rows x 3 columns]

# %%
# Find all episodes present in qrels
in_qrels = metadf.loc[metadf['episode_uri'].isin(qrel['episode_uri'].unique())]

# Check for NaN and empty string entries
null_or_empty = in_qrels[in_qrels['episode_description'].isna() | (in_qrels['episode_description'] == '')]

# Check for one-word descriptions
def one_word(row):
    return re.search(r'.*\s', row.episode_description)

one_word_descr = list(in_qrels.index[in_qrels.apply(one_word, axis=1).isna()])
one_word_descr
# Out:
# [3972, 101227]

# %%
# Find all episodes present in qrels
qrel_uris = set(qrel['episode_uri'].unique())
in_qrels = metadf[metadf['episode_uri'].isin(qrel_uris)]

# Check for NaN and empty string entries
null_or_empty = in_qrels[in_qrels['episode_description'].isna() | (in_qrels['episode_description'] == '')]

# Check for one-word descriptions
one_word_descr = in_qrels[in_qrels['episode_description'].str.count(' ') == 0]

# Remove QRels with one-word episode descriptions
qrel = qrel[~qrel['episode_uri'].isin(one_word_descr['episode_uri'])].reset_index(drop=True)

# Find indices of NaN and empty string entries
null_idxs = in_qrels[in_qrels['episode_description'].isna()].index
empty_idxs = in_qrels[in_qrels['episode_description'] == ''].index

# Check for one-word descriptions using a lambda function
one_word_descr = in_qrels[in_qrels.apply(lambda x: len(x['episode_description'].split()) == 1, axis=1)]
one_word_descr
# Out:
#                                    episode_uri  \
# 3972    spotify:episode:0HxLcyXXoVhVYUD0aIFYQj
# 12798   spotify:episode:0wFCxK3L96rqgN2Pn0E6i6
# 16014   spotify:episode:1B9lIDYV3ZBKdt4lgHRK7J
# 19495   spotify:episode:1REBtFG27yBSdkt5KSdjla
# 20508   spotify:episode:1VrQT8rB9KA0fsHCAo5kdJ
# 30823   spotify:episode:2Ggbm0HKW7HJRMmAP24YSl
# 33285   spotify:episode:2RWrlYKhYqSAIDM4JcC0Is
# 33767   spotify:episode:2Tf6Cs5DIfIYgnDp1tsOAJ
# 35559   spotify:episode:2bjO0LTkno3kTSa2nFR3dm
# 44766   spotify:episode:3HrYAqEyk2gZHMa8CRA2Fp
# 45768   spotify:episode:3MPDTtpBbbqxMZw43hZlrJ
# 54165   spotify:episode:3yJFJ3B45rKFhIoyZ3POvY
# 73238   spotify:episode:5Oh2dJZ3bqqtYekTLSVOsZ
# 73942   spotify:episode:5RnREQeAWFLxxPedJtbsmG
# 79475   spotify:episode:5rIQKp5lYYXBnbH5LvkOlX
# 82630   spotify:episode:65q67kuqMuTtYlViaPuOpY
# 93322   spotify:episode:6tbcLL8WR90zmyTOXLec2i
# 101227  spotify:episode:7gYQvDe2wguALKVD9WD2hw
# 102731  spotify:episode:7nQsCo0itzVm7oautpoFXX
#
#                                                 show_name  \
# 3972                              The Rewind with Guy Raz
# 12798                Bar Prep For Sufferers In UBE States
# 16014                                      Levels podcast
# 19495                                Revolution Ramblings
# 20508                                       UPSC Podcasts
# 30823                                     Zendaya Podcast
# 33285                Bar Prep For Sufferers In UBE States
# 33767                                       UPSC Podcasts
# 35559                                    Excuse My French
# 44766       Eating Disorders Anonymous (EDA) Speaker Feed
# 45768                                       UPSC Podcasts
# 54165                                       UPSC Podcasts
# 73238                                       UPSC Podcasts
# 73942                                       UPSC Podcasts
# 79475                                        Planet Sach
# 82630            Michelle Obama: Forever Changing History
# 93322                                       UPSC Podcasts
# 101227                                                PRA
# 102731  APES Case Study 93 - Chernobyl: The Worlds Wor...
#
#                                          show_description  \
# 3972    Guy Raz digs into the stories behind some of t...
# 12798                                        Death by UBE
# 16014   No ones doin it up like is at this age  Hosts ...
# 19495   Stream of consciousness podcast by Youtube Ast...
# 20508   Podcasts useful for UPSC aspirants! Mainly dis...
# 30823                                 Leadership Podcast
# 33285                                        Death by UBE
# 33767   Podcasts useful for UPSC aspirants! Mainly dis...
# 35559   A French Woman from Paris living in LA sharing...
# 44766   Hear stories of experience, strength, and hope...
# 45768   Podcasts useful for UPSC aspirants! Mainly dis...
# 54165   Podcasts useful for UPSC aspirants! Mainly dis...
# 73238   Podcasts useful for UPSC aspirants! Mainly dis...
# 73942   Podcasts useful for UPSC aspirants! Mainly dis...
# 79475   Welcome to Planet Sach! Dive into my world whi...
# 82630   Michelle Obama  Cover art photo provided by Jo...
# 93322   Podcasts useful for UPSC aspirants! Mainly dis...
# 101227
# 102731                                         Chernobyl
#
#                                              episode_name episode_description  \
# 3972                                             Jessie J                 nan
# 12798                                            Evidence              proof
# 16014                                     LEVEL 1 - Pilot              Pilot
# 19495                                                   X                  🖤
# 20508   Innovation, Technology & Team Work - Crucial P...                  .
# 30823                                 Leadership Podcast             Zendaya
# 33285                                          Family Law                fam
# 33767         Bilateral Relations between India and China                  .
# 35559                  France, the holidays and wholefood                  .
# 44766                    Steps Workshop - Step 12 - Trish           12.14.19
# 45768   Prime Minister’s Interaction with Global Busin...                  .
# 54165   Development of Jammu and Kashmir: A Priority o...                  .
# 73238    Assessment of Performance of Public Sector Banks                  .
# 73942   Prime Minister Address to the United Nations G...                  .
# 79475                                The Three Unwise Men               ....
# 82630                                     Michelle Obama             english
# 93322   Significance of PM’s Visit to United States of...                  .
# 101227                               VICE Movie, RM, CPAC                 nan
# 102731  APES Case Study 93 - Chernobyl: The Worlds wor...         Chernobyl
#
#          docno
# 3972      3972
# 12798    12798
# 16014    16014
# 19495    19495
# 20508    20508
# 30823    30823
# 33285    33285
# 33767    33767
# 35559    35559
# 44766    44766
# 45768    45768
# 54165    54165
# 73238    73238
# 73942    73942
# 79475    79475
# 82630    82630
# 93322    93322
# 101227  101227
# 102731  102731

# %%
# Remove QRels with one-word episode descriptions using boolean indexing
qrel = qrel[~qrel['episode_uri'].isin(one_word_descr['episode_uri'])].reset_index(drop=True)
qrel.shape
# Out:
# (5738, 3)

# %%
# create dict {episode_uri: doc}
docno_dict = dict(metadf[['episode_uri', 'docno']].values)

# insert docno for each episode_uri in qrels using dict
qrel['docno'] = qrel['episode_uri'].map(docno_dict)

# rename columns and change data types to make qrels compatible with PyTerrier
qrel = qrel.rename(columns={'query': 'qid', 'relevance': 'label'})
qrel['qid'] = qrel['qid'].astype(str)
qrel['label'] = qrel['label'].astype(int)  # Convert the 'label' column to integers
qrel = qrel[['qid', 'docno', 'label']]

# display qrels
qrel
# Out:
#      qid   docno  label
# 0      1    3096      2
# 1      1    6496      1
# 2      1   15551      2
# 3      1   21291      2
# 4      1   24523      0
# ...   ..     ...    ...
# 5733   9   93648      1
# 5734   9   97871      0
# 5735   9   99768      0
# 5736   9  102459      0
# 5737   9  102562      0
#
# [5738 rows x 3 columns]

# %% [markdown]
# <div style="background-color: #090e60; padding: 10px; border: 8px solid  white;">
#     <p style="text-align: center; font-weight: bold; color: white; font-size: 30px; margin: 0; position: relative; top: 50%; transform: translateY(-50%); font-family: 'Italianno', cursive;">&ndash;&ndash;&ndash;&nbsp;Demo&nbsp;&ndash;&ndash;&ndash;
#     </p>
# </div>

# %%
metadf.head()
# Out:
#                               episode_uri  \
# 0  spotify:episode:000A9sRBYdVh66csG2qEdj
# 1  spotify:episode:000HP8n3hNIfglT2wSI2cA
# 2  spotify:episode:001UfOruzkA3Bn1SPjcdfa
# 3  spotify:episode:001i89SvIQgDuuyC53hfBm
# 4  spotify:episode:0025RWNwe2lnp6HcnfzwzG
#
#                                            show_name  \
# 0                               Kream in your Koffee
# 1                              Morning Cup Of Murder
# 2  Inside The 18 : A Podcast for Goalkeepers by G...
# 3                                    Arrowhead Live!
# 4                                              FBoL
#
#                                     show_description  \
# 0  A 20-something blunt female takes on the world...
# 1  Ever wonder what murder took place on today in...
# 2  Inside the 18 is your source for all things Go...
# 3  Your favorite podcast for everything @Chiefs! ...
# 4  The comedy podcast about toxic characters, wri...
#
#                                         episode_name  \
# 0                            1: It’s Christmas Time!
# 1  The Goleta Postal Facility shootings- January ...
# 2  Ep.36 - Incorporating a Singular Goalkeeping C...
# 3                   Episode 1: Arrowhead Live! Debut
# 4  The Lion, The Witch, And The Wardrobe - Ashley...
#
#                                  episode_description docno
# 0  On the first ever episode of Kream in your Kof...     0
# 1  See something, say something. It’s a mantra ma...     1
# 2  Today’s episode is a sit down Michael and Omar...     2
# 3  Join us as we take a look at all current Chief...     3
# 4  The modern morality tail of how to stay good f...     4

# %%
short_query.head()
# Out:
#   qid                          query
# 0   1             coronavirus spread
# 1   2  greta thunberg cross atlantic
# 2   3               black hole image
# 3   4      story about riding a bird
# 4   5            daniel ek interview

# %%
full_query.head()
# Out:
#   qid                                              query
# 0   1  What were people saying about the spread of th...
# 1   2  What were people saying about Greta Thunbergs ...
# 2   3  In May 2019 astronomers released the firstever...
# 3   4  I remember hearing a podcast that had a story ...
# 4   5  Someone told me about a podcast interview with...

# %%
qrel.head()
# Out:
#   qid  docno  label
# 0   1   3096      2
# 1   1   6496      1
# 2   1  15551      2
# 3   1  21291      2
# 4   1  24523      0

# %%
# Installing PyTerrier
# !pip install python-terrier
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: python-terrier in /usr/local/lib/python3.9/dist-packages (0.9.2)
# Requirement already satisfied: nptyping==1.4.4 in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.4.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from python-terrier) (4.65.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from python-terrier) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.5.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.9/dist-packages (from python-terrier) (0.3.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.2.2)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.2.13)
# Requirement already satisfied: ir-datasets>=0.3.2 in /usr/local/lib/python3.9/dist-packages (from python-terrier) (0.5.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from python-terrier) (2.27.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.9/dist-packages (from python-terrier) (0.13.5)
# Requirement already satisfied: matchpy in /usr/local/lib/python3.9/dist-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: wget in /usr/local/lib/python3.9/dist-packages (from python-terrier) (3.2)
# Requirement already satisfied: pyjnius>=1.4.2 in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.4.2)
# Requirement already satisfied: ir-measures>=0.3.1 in /usr/local/lib/python3.9/dist-packages (from python-terrier) (0.3.1)
# Requirement already satisfied: chest in /usr/local/lib/python3.9/dist-packages (from python-terrier) (0.2.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.2.0)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in /usr/local/lib/python3.9/dist-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from python-terrier) (9.1.0)
# Requirement already satisfied: typish>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from nptyping==1.4.4->python-terrier) (1.9.3)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.9/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.9/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.5)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.9/dist-packages (from ir-datasets>=0.3.2->python-terrier) (3.2.0.post0)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.9)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.9/dist-packages (from ir-datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from ir-datasets>=0.3.2->python-terrier) (4.11.2)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.9/dist-packages (from ir-datasets>=0.3.2->python-terrier) (4.9.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from ir-datasets>=0.3.2->python-terrier) (6.0)
# Requirement already satisfied: lz4>=3.1.1 in /usr/local/lib/python3.9/dist-packages (from ir-datasets>=0.3.2->python-terrier) (4.3.2)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.2)
# Requirement already satisfied: cwl-eval>=1.0.10 in /usr/local/lib/python3.9/dist-packages (from ir-measures>=0.3.1->python-terrier) (1.0.12)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from pyjnius>=1.4.2->python-terrier) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->python-terrier) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->python-terrier) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->python-terrier) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->python-terrier) (1.26.15)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.9/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->python-terrier) (2.1.2)
# Requirement already satisfied: multiset<3.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from matchpy->python-terrier) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->python-terrier) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->python-terrier) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels->python-terrier) (23.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels->python-terrier) (0.5.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (2.4)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier) (1.0.0)

# %%
import pyterrier as pt
import numpy as np
import pandas as pd

def initialize_pt():
    if not pt.started():
        pt.init()

def remove_index_folder():
    # !rm -rf ./pd_index

def create_index(metadf):
    pd_indexer = pt.DFIndexer("./pd_index")
    index = pd_indexer.index(metadf["episode_description"], metadf["docno"])
    return index

def get_index_file(index):
    return pt.IndexFactory.of(index)

def print_collection_stats(index_file):
    print(index_file.getCollectionStatistics())

initialize_pt()
remove_index_folder()
index = create_index(metadf)
index_file = get_index_file(index)
print_collection_stats(index_file)
# Out:
# 16:41:14.989 [main] WARN org.terrier.structures.indexing.Indexer - Adding an empty document to the index (5) - further warnings are suppressed
# /usr/local/lib/python3.9/dist-packages/pyterrier/index.py:628: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, value in meta_column[1].iteritems():
# 16:42:42.356 [main] WARN org.terrier.structures.indexing.Indexer - Indexed 255 empty documents
# Number of documents: 105360
# Number of terms: 131456
# Number of postings: 4124038
# Number of fields: 0
# Number of tokens: 5453411
# Field names: []
# Positions:   false

# %%
def get_example_index(docid, index_file):
    di = index_file.getDirectIndex()
    doi = index_file.getDocumentIndex()
    lex = index_file.getLexicon()
    example_index = pd.DataFrame(columns=['Term', 'Frequency'])
    
    for posting in di.getPostings(doi.getDocumentEntry(docid)):
        termid = posting.getId()
        lee = lex.getLexiconEntry(termid)
        term_freq = pd.DataFrame([[str(lee.getKey()), str(posting.getFrequency())]], columns=['Term', 'Frequency'])
        example_index = example_index.append(term_freq)

    example_index = example_index.reset_index(drop=True)
    return example_index

# %%
def print_episode_info(docid, metadf):
    show_name = metadf.loc[metadf.docno == str(docid)].show_name.values[0]
    episode_name = metadf.loc[metadf.docno == str(docid)].episode_name.values[0]
    episode_description = metadf.loc[metadf.docno == str(docid)].episode_description.values[0]
    
    print(f'show name: {show_name}')
    print(f'episode name: {episode_name}')
    print(f'episode description: {episode_description}')

# %%
docid = 6
example_index = get_example_index(docid, index_file)
print_episode_info(docid, metadf)

bm25 = pt.BatchRetrieve(index, wmodel='BM25')
pl2 = pt.BatchRetrieve(index, wmodel='PL2')
# Out:
# show name: The Feminization Boudoir
# episode name: The Sissy's Mentor (Part 5)
# episode description: Miss Jenn Davis reads the final part of The Sissy's Mentor.  It's the story of a young inexperienced college freshman and the dominant woman who takes him under her wing or is that wig?   You can find a lot more great erotic content from Jenn at MissJennDavis.com. Remember that this podcast plays clips (Usually 40%-50%) from audios.  At least half the show is missing and in that half are the very sexiest parts. Please support Candy Apple Press at our clipsites: IWantClips Clips4Sale and buy our books: Amazon.com You can also donate to the Podcast directly at Anchor.fm.  Wherever you listen, please give us good feedback. Thanks, Kylie  ---   This episode is sponsored by  · Anchor: The easiest way to make a podcast.  https://anchor.fm/app  Support this podcast: https://anchor.fm/kylie-gable/support
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)
# <ipython-input-132-a140ada847fb>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   example_index = example_index.append(term_freq)

# %%
models_list = [bm25, pl2]

exp_df_short = pt.Experiment(
    models_list,
    short_query,
    qrel,
    eval_metrics=eval_metrics_list,
    names=['BM25', 'PL2']
)
print(exp_df_short.sort_values(by=['map'], ascending=False)[:5])
# Out:
#    name       map      ndcg  recip_rank       R@5      R@10      R@15  \
# 0  BM25  0.127050  0.290382    0.509473  0.135931  0.163656  0.181625
# 1   PL2  0.124207  0.286858    0.506501  0.131175  0.158539  0.176847
#
#        R@20      R@30     R@100     R@200     R@500    R@1000        mrt
# 0  0.194193  0.212797  0.284753  0.320845  0.359622  0.376515  27.992090
# 1  0.184776  0.201197  0.282072  0.319046  0.357215  0.376516  32.950439

# %%
models_list = [bm25, pl2]

exp_df_short = pt.Experiment(
    models_list,
    full_query,
    qrel,
    eval_metrics=eval_metrics_list,
    names=['BM25', 'PL2']
)
print(exp_df_short.sort_values(by=['map'], ascending=False)[:5])
# Out:
#    name       map      ndcg  recip_rank       R@5      R@10      R@15  \
# 0  BM25  0.121408  0.282391    0.478899  0.120789  0.140971  0.176937
# 1   PL2  0.113027  0.270138    0.460196  0.111716  0.129386  0.148549
#
#        R@20      R@30     R@100     R@200     R@500    R@1000        mrt
# 0  0.185512  0.202482  0.267562  0.303330  0.348212  0.395465  35.987806
# 1  0.165298  0.196600  0.254190  0.286587  0.342082  0.390185  40.520484
