# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: joblib in ./venv/lib/python3.9/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: tqdm in ./venv/lib/python3.9/site-packages (from nltk) (4.65.0)
# Collecting regex>=2021.8.3
#   Using cached regex-2023.3.23-cp39-cp39-macosx_10_9_x86_64.whl (294 kB)
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Installing collected packages: regex, click, nltk
# Successfully installed click-8.1.3 nltk-3.8.1 regex-2023.3.23
# WARNING: You are using pip version 20.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import string
import re
from sklearn.feature_extraction.text import CountVectorizer

from nltk.util import ngrams
from nltk.stem import WordNetLemmatizer  # lemmatization
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

# %%
data = pd.read_csv('metadata.tsv', sep = '\t')

# %%
data.head()
# Out:
#                               show_uri
# 0  spotify:show:2NYtxEZyYelR6RMKmjfPLB  \
# 1  spotify:show:15iWCbU7QoO23EndPEO6aN
# 2  spotify:show:6vZRgUFTYwbAA79UNCADr4
# 3  spotify:show:5BvKEjaMSuvUsGROGi2S7s
# 4  spotify:show:7w3h3umpH74veEJcbE6xf4
#
#                                            show_name
# 0                               Kream in your Koffee  \
# 1                              Morning Cup Of Murder
# 2  Inside The 18 : A Podcast for Goalkeepers by G...
# 3                                    Arrowhead Live!
# 4                                              FBoL
#
#                                     show_description               publisher
# 0  A 20-something blunt female takes on the world...             Katie Houle  \
# 1  Ever wonder what murder took place on today in...   Morning Cup Of Murder
# 2  Inside the 18 is your source for all things Go...  Inside the 18 GK Media
# 3  Your favorite podcast for everything @Chiefs! ...         Arrowhead Live!
# 4  The comedy podcast about toxic characters, wri...           Emily Edwards
#
#     language                                           rss_link
# 0     ['en']           https://anchor.fm/s/11b84b68/podcast/rss  \
# 1     ['en']            https://anchor.fm/s/b07181c/podcast/rss
# 2     ['en']            https://anchor.fm/s/81a072c/podcast/rss
# 3  ['en-US']            https://anchor.fm/s/917dba4/podcast/rss
# 4     ['en']  https://www.fuckboisoflit.com/episodes?format=rss
#
#                               episode_uri
# 0  spotify:episode:000A9sRBYdVh66csG2qEdj  \
# 1  spotify:episode:000HP8n3hNIfglT2wSI2cA
# 2  spotify:episode:001UfOruzkA3Bn1SPjcdfa
# 3  spotify:episode:001i89SvIQgDuuyC53hfBm
# 4  spotify:episode:0025RWNwe2lnp6HcnfzwzG
#
#                                         episode_name
# 0                            1: It’s Christmas Time!  \
# 1  The Goleta Postal Facility shootings- January ...
# 2  Ep.36 - Incorporating a Singular Goalkeeping C...
# 3                   Episode 1: Arrowhead Live! Debut
# 4  The Lion, The Witch, And The Wardrobe - Ashley...
#
#                                  episode_description   duration
# 0  On the first ever episode of Kream in your Kof...  12.700133  \
# 1  See something, say something. It’s a mantra ma...   6.019383
# 2  Today’s episode is a sit down Michael and Omar...  43.616333
# 3  Join us as we take a look at all current Chief...  58.189200
# 4  The modern morality tail of how to stay good f...  51.782050
#
#           show_filename_prefix episode_filename_prefix
# 0  show_2NYtxEZyYelR6RMKmjfPLB  000A9sRBYdVh66csG2qEdj
# 1  show_15iWCbU7QoO23EndPEO6aN  000HP8n3hNIfglT2wSI2cA
# 2  show_6vZRgUFTYwbAA79UNCADr4  001UfOruzkA3Bn1SPjcdfa
# 3  show_5BvKEjaMSuvUsGROGi2S7s  001i89SvIQgDuuyC53hfBm
# 4  show_7w3h3umpH74veEJcbE6xf4  0025RWNwe2lnp6HcnfzwzG

# %%
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

# pre-processing
def pre_process(text):
    punctuation_marks = string.punctuation.replace("'", "")
    
    #converts to lower case
    if preprocessing_switches['convert_to_lowercase']:    
        text = text.lower()
    
    # separate punctuation from words - preserving apostrophe
    if preprocessing_switches['separate_out_punctuation']:
        for c in punctuation_marks:
            text = text.replace(c, ' ' + c + ' ')
    
    #converting numbers to digits
    if preprocessing_switches["convert_number_words_to_digits"]:
        text = text2int(text)   
    
    #removing numbers
    if preprocessing_switches["convert_numbers"]:
        text = re.sub('\d+', 'NUMBER',text)
        text = text.replace('NUMBER ', '')
    
    # Tokenize the text
    tokens = text.split()
    
    # Remove stopwords
    if preprocessing_switches['separate_out_punctuation']:    
        stop_words = set(stopwords.words("english"))
        tokens = [token for token in tokens if token not in stop_words]
    
    # Remove punctuation
    if preprocessing_switches['remove_punctuation']:    
        tokens = [token for token in tokens if token not in punctuation_marks]
    
    # Lemmatize the tokens
    if preprocessing_switches['apply_lemmatization']:
        tokens = [lemmatizer.lemmatize(token) for token in tokens]
        
    # Stem the tokens
    if preprocessing_switches['stem_tokens']:
        tokens = [stemmer.stem(token) for token in tokens]
    return ' '.join(tokens)

# %%
preprocessing_switches = {'convert_to_lowercase': True,
                            'separate_out_punctuation': True,
                            'remove_punctuation': True,
                            'convert_number_words_to_digits': True,
                            'convert_numbers': True,
                            'remove_stopwords': True,
                            'apply_lemmatization': True,
                            'stem_tokens': False}

# %%
def text2int(textnum, numwords={}):
    if not numwords:
        units = [
        "zero", "one", "two", "three", "four", "five", "six", "seven", "eight",
        "nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen",
        "sixteen", "seventeen", "eighteen", "nineteen",
        ]

        tens = ["", "", "twenty", "thirty", "forty", "fifty", "sixty", "seventy", "eighty", "ninety"]

        scales = ["hundred", "thousand", "million", "billion", "trillion"]

        numwords["and"] = (1, 0)
        for idx, word in enumerate(units):  numwords[word] = (1, idx)
        for idx, word in enumerate(tens):       numwords[word] = (1, idx * 10)
        for idx, word in enumerate(scales): numwords[word] = (10 ** (idx * 3 or 2), 0)

    ordinal_words = {'first':1, 'second':2, 'third':3, 'fifth':5, 'eighth':8, 'ninth':9, 'twelfth':12}
    ordinal_endings = [('ieth', 'y'), ('th', '')]

    textnum = textnum.replace('-', ' ')

    current = result = 0
    curstring = ""
    onnumber = False
    for word in textnum.split():
        if word in ordinal_words:
            scale, increment = (1, ordinal_words[word])
            current = current * scale + increment
            if scale > 100:
                result += current
                current = 0
            onnumber = True
        else:
            for ending, replacement in ordinal_endings:
                if word.endswith(ending):
                    word = "%s%s" % (word[:-len(ending)], replacement)

            if word not in numwords:
                if onnumber:
                    curstring += repr(result + current) + " "
                curstring += word + " "
                result = current = 0
                onnumber = False
            else:
                scale, increment = numwords[word]

                current = current * scale + increment
                if scale > 100:
                    result += current
                    current = 0
                onnumber = True

    if onnumber:
        curstring += repr(result + current)

    return curstring

# %%
#create subset for processing and apply pre-processing
data_subset = data.loc[:10000]

data_processed = data_subset['show_description'].apply(pre_process).to_list()

# %%
vectorizer = CountVectorizer()
documents_vectorized = vectorizer.fit_transform(data_processed)
vocabulary = vectorizer.get_feature_names_out()

# %%
dataframe = pd.DataFrame(documents_vectorized.toarray(), columns=vocabulary)

# removing low word counts to improve performance - low word counts also not likely to be relevant
word_counts = dataframe.sum(axis=0)
to_remove = word_counts[word_counts <4].index
dataframe = dataframe.drop(columns = to_remove)
dataframe.shape
# Out:
# (10001, 7255)

# %%
#term frequencies
dfs = (dataframe > 0).sum(axis=0)
#idfs
N = dataframe.shape[0]
idfs = np.log10(N/dfs)
#BM25
k_1 = 1.2
b = 0.8

# The following line of code considers all words in each document:
dls_all = [len(d.split(' ')) for d in data_processed] # vector

# But we're not intrested in stop words, therefore, let's do the following: 
dls = dataframe.sum(axis=1).tolist()  # document lengths in words
avgdl = np.mean(dls) # avarage document length

numerator = np.array((k_1 + 1) * dataframe)
denominator = np.array(k_1 *((1 - b) + b * (dls / avgdl))).reshape(N, 1) + \
                       np.array(dataframe)

BM25_tf = numerator / denominator

idfs = np.array(idfs)  # inverse document frequencies

BM25_score = idfs * BM25_tf

# %%
bm25_idf = pd.DataFrame(BM25_score, columns=dataframe.columns)
bm25_idf['christmas'].sort_values(ascending = False)
# Out:
# 7392     4.805475
# 2077     3.856923
# 6765     3.856923
# 9530     3.856923
# 2084     3.720322
#            ...
# 3335     0.000000
# 3336     0.000000
# 3337     0.000000
# 3338     0.000000
# 10000    0.000000
# Name: christmas, Length: 10001, dtype: float64

# %%
data.loc[7392]
# Out:
# show_uri                                 spotify:show:2TPE8nsTVHyRkaVmQTbKbW
# show_name                                               61 Days of Christmas
# show_description           Hosts Abby and Kelsy watch the 40 new Hallmark...
# publisher                                      61 Days of Hallmark Christmas
# language                                                              ['en']
# rss_link                            https://anchor.fm/s/1004fcbc/podcast/rss
# episode_uri                           spotify:episode:0XgrKcGfkaf3cwGxkwKe5e
# episode_name                 Christmas Wishes & Mistletoe Kisses Snoozefest
# episode_description        Hosts Abby and Kelsy recount the exhausting fi...
# duration                                                           57.212417
# show_filename_prefix                             show_2TPE8nsTVHyRkaVmQTbKbW
# episode_filename_prefix                               0XgrKcGfkaf3cwGxkwKe5e
# Name: 7392, dtype: object

# %%
query = 'christmas'
columns = ['show_name', 'show_description', 'publisher']

query_words = pre_process(query).split(' ')
top_results = bm25_idf[query_words].sum(axis = 1).sort_values(ascending = False).index[:5].tolist()
data.loc[top_results, columns]
# Out:
#                                        show_name
# 7392                        61 Days of Christmas  \
# 2077  A Cup Of Cheer: A Seasonal Holiday Podcast
# 6765  A Cup Of Cheer: A Seasonal Holiday Podcast
# 9530  A Cup Of Cheer: A Seasonal Holiday Podcast
# 2084                             MC Crue Podcast
#
#                                        show_description
# 7392  Hosts Abby and Kelsy watch the 40 new Hallmark...  \
# 2077  We don’t know if there will be snow, so have a...
# 6765  We don’t know if there will be snow, so have a...
# 9530  We don’t know if there will be snow, so have a...
# 2084  On this podcast, we'll be talking about anythi...
#
#                           publisher
# 7392  61 Days of Hallmark Christmas
# 2077                           DeeJ
# 6765                           DeeJ
# 9530                           DeeJ
# 2084                  Wolfpac Media

# %%
# from sqlalchemy import create_engine
# engine = create_engine('sqlite:///IRDB', echo=False)
# bm25_idf.to_sql('users', con=engine)

(bm25_idf.memory_usage(deep = True).sum()) / (1024 * 1024)
bm25_idf.to_csv('Web Page/BM25_data.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 6
#       1 # from sqlalchemy import create_engine
#       2 # engine = create_engine('sqlite:///IRDB', echo=False)
#       3 # bm25_idf.to_sql('users', con=engine)
#       5 (bm25_idf.memory_usage(deep = True).sum()) / (1024 * 1024)
# ----> 6 bm25_idf.to_csv('Web Page/BM25_data.csv')
#
# File ~/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File ~/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/io/formats/format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File ~/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/io/formats/csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File ~/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/io/common.py:737, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     735 # Only for write methods
#     736 if "r" not in mode and is_path:
# --> 737     check_parent_directory(str(handle))
#     739 if compression:
#     740     if compression != "zstd":
#     741         # compression libraries do not like an explicit text-mode
#
# File ~/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/io/common.py:600, in check_parent_directory(path)
#     598 parent = Path(path).parent
#     599 if not parent.is_dir():
# --> 600     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'Web Page'

# %%
data.loc[2084, 'show_description']

# %% [markdown]
# <div style="background-color: #090e60; padding: 10px; border: 8px solid  white;">
#     <p style="text-align: center; font-weight: bold; color: white; font-size: 30px; margin: 0; position: relative; top: 50%; transform: translateY(-50%); font-family: 'Italianno', cursive;">&ndash;&ndash;&ndash;&nbsp;Queries&nbsp;&ndash;&ndash;&ndash;
#     </p>
# </div>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

urls = [
    "https://trecpodcasts.github.io/resources/podcasts_2020_topics_train.xml",
    "https://trecpodcasts.github.io/resources/podcasts_2020_topics_test.xml"
]

tables = []
for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content)
    rows = soup.find_all("topic")

    # Create dict with column headings and empty lists
    table_dict = {"num": [], "query": [], "type": [], "description": []}

    # For every row in the table, find each cell element and add it to the list
    for row in rows:
        table_dict = {
            col: table_dict[col] + [row.find(col).text] for col in table_dict
        }

    table = pd.DataFrame(table_dict)
    table = table.applymap(lambda x: x[0] if isinstance(x, list) else x)
    tables.append(table)

query = pd.concat(tables, ignore_index=True)
query.head()
# Out:
#   num                          query        type
# 0   1             coronavirus spread     topical  \
# 1   2  greta thunberg cross atlantic     topical
# 2   3               black hole image     topical
# 3   4      story about riding a bird   refinding
# 4   5            daniel ek interview  known item
#
#                                          description
# 0  What were people saying about the spread of th...
# 1  What were people saying about Greta Thunberg’s...
# 2  In May 2019 astronomers released the first-eve...
# 3  I remember hearing a podcast that had a story ...
# 4  Someone told me about a podcast interview with...

# %%
query = query[~query['num'].isin(['47', '50'])].reset_index(drop=True)
query
# Out:
#    num                                query        type
# 0    1                   coronavirus spread     topical  \
# 1    2        greta thunberg cross atlantic     topical
# 2    3                     black hole image     topical
# 3    4            story about riding a bird   refinding
# 4    5                  daniel ek interview  known item
# 5    6              michelle obama becoming     topical
# 6    7                          anna delvey     topical
# 7    8            facebook stock prediction     topical
# 8    9       trump call ukrainian president     topical
# 9   10              boeing 737 crash causes     topical
# 10  11                   how to cook turkey     topical
# 11  12                    imran khan career     topical
# 12  13              drug addiction recovery     topical
# 13  14               near death experiences     topical
# 14  15               podcast about podcasts     topical
# 15  16   causes and prevention of wildfires     topical
# 16  17                time between meetings     topical
# 17  18                        women in stem     topical
# 18  19                     ai in healthcare     topical
# 19  20                    cost of childcare     topical
# 20  21                           juneteenth     topical
# 21  22                        chernobyl hbo     topical
# 22  23                      notre dame fire     topical
# 23  24          france yellow vest protests     topical
# 24  25                   black lives matter     topical
# 25  26                         bob woodward     topical
# 26  27         civil rights protest stories     topical
# 27  28                        yo-yo dieting     topical
# 28  29                     racism in canada     topical
# 29  30                           motherhood     topical
# 30  31             horoscope reading cancer     topical
# 31  32              giants game december 22     topical
# 32  33       hvac industry environmentalism     topical
# 33  34           halloween stories and chat     topical
# 34  35                     living debt free     topical
# 35  36                 cryptocurrency risks     topical
# 36  37                          slow travel     topical
# 37  38                  workplace diversity     topical
# 38  39               social media marketing     topical
# 39  40                           bees dying     topical
# 40  41                    gmo food labeling     topical
# 41  42                        fyre festival     topical
# 42  43                   hong kong protests     topical
# 43  44          thanksgiving comedy special   refinding
# 44  45                  drafting tight ends   refinding
# 45  46                   missouri quilt mom   refinding
# 46  48                spike lee movie score   refinding
# 47  49                   thrift store smell   refinding
# 48  51                    queer eye veteran   refinding
# 49  52                      fauci interview  known item
# 50  53  recommended books for entrepreneurs  known item
# 51  54           bias in college admissions  known item
# 52  55                  malcolm x biography  known item
# 53  56                          gaslighting  known item
# 54  57                            nefertiti  known item
# 55  58                   sam bush interview  known item
#
#                                           description
# 0   What were people saying about the spread of th...
# 1   What were people saying about Greta Thunberg’s...
# 2   In May 2019 astronomers released the first-eve...
# 3   I remember hearing a podcast that had a story ...
# 4   Someone told me about a podcast interview with...
# 5   Former First Lady Michelle Obama’s memoir Beco...
# 6   Anna Sorokina moved to New York City in 2013 a...
# 7   After Facebook’s Q4 2018 earnings call, what w...
# 8   The White House released a rough transcript of...
# 9   The Boeing 737 MAX passenger airliner was grou...
# 10  I’m looking for podcasts that talk about how t...
# 11  Imran Khan is the 22nd Prime Minister of Pakis...
# 12  I’m interested in hearing personal stories of ...
# 13  I wonder if people have shared near-death expe...
# 14  I would like to start a podcast.  What equipme...
# 15  2019 saw a large number of wildfires, in Austr...
# 16  I am looking for some ideas for things to do d...
# 17  I’d like to hear personal stories from women i...
# 18  How can artificial intelligence be used to imp...
# 19  I’m looking for personal stories from people t...
# 20  What does Juneteenth mean to people in the US?...
# 21  The series Chernobyl aired on HBO in 2019.  Wh...
# 22  The 2019 fire at Notre Dame cathedral in Paris...
# 23  What do people think were the causes of the ye...
# 24  What do people mean when they say “black lives...
# 25  I am looking for podcast episodes about Bob Wo...
# 26  I’d like to hear stories about protests and pr...
# 27  What is yo-yo dieting?  What are the benefits ...
# 28  How does racism appear in Canada?  I’m looking...
# 29  I want to hear podcast episodes with new mothe...
# 30  I’d like to hear horoscopes for my zodiac sign...
# 31  I want to hear about the NY-Washington NFL foo...
# 32  What is the HVAC industry doing to promote sus...
# 33  I love Halloween and I want to hear stories an...
# 34  What can I do to achieve a debt-free life?  Wh...
# 35  What are the risks of investing in cryptocurre...
# 36  What is “slow travel”?  I heard about this app...
# 37  What are things companies are doing and could ...
# 38  I’m looking for tips and suggestions for creat...
# 39  There have been numerous news reports of bees ...
# 40  \nSome people say we should avoid foods with g...
# 41  Fyre Festival was a failed music festival whic...
# 42  Since early 2019, more or less continuous prot...
# 43  I remember hearing on the radio a comedy speci...
# 44  I heard a podcast about strategies for draftin...
# 45  I listened to a podcast about a stay-at-home m...
# 46  Spike Lee movies have well curated scores.  I ...
# 47  I want to find an episode I heard about the sc...
# 48  I heard a podcast featuring a US military vete...
# 49  An article about COVID-19 referenced an interv...
# 50  I was told about a podcast that recommended go...
# 51  I read an article that mentioned a podcast abo...
# 52  I heard about a podcast biography of Malcolm X...
# 53  On Twitter I saw someone reference a podcast i...
# 54  I want to hear a podcast I know about that is ...
# 55  A bluegrass magazine I read mentioned a podcas...

# %%
short_query = query.loc[:, ['num', 'query']].rename(columns={'num': 'query_id','query': 'short_query'})
short_query.head()
# Out:
#   query_id                    short_query
# 0        1             coronavirus spread
# 1        2  greta thunberg cross atlantic
# 2        3               black hole image
# 3        4      story about riding a bird
# 4        5            daniel ek interview

# %%
long_query = query.loc[:, ['num', 'description']].rename(columns={'num': 'query_id','description': 'long_query'})
long_query.head()
# Out:
#   query_id                                         long_query
# 0        1  What were people saying about the spread of th...
# 1        2  What were people saying about Greta Thunberg’s...
# 2        3  In May 2019 astronomers released the first-eve...
# 3        4  I remember hearing a podcast that had a story ...
# 4        5  Someone told me about a podcast interview with...

# %%
def remove_non_alphanumeric(row):
    return re.sub(r'[^a-zA-Z0-9 ]+', '', row.long_query)

long_query['long_query'] = long_query.apply(remove_non_alphanumeric, axis=1)
long_query.head()
# Out:
#   query_id                                         long_query
# 0        1  What were people saying about the spread of th...
# 1        2  What were people saying about Greta Thunbergs ...
# 2        3  In May 2019 astronomers released the firstever...
# 3        4  I remember hearing a podcast that had a story ...
# 4        5  Someone told me about a podcast interview with...

# %% [markdown]
# <div style="background-color: #090e60; padding: 10px; border: 8px solid  white;">
#     <p style="text-align: center; font-weight: bold; color: white; font-size: 30px; margin: 0; position: relative; top: 50%; transform: translateY(-50%); font-family: 'Italianno', cursive;">&ndash;&ndash;&ndash;&nbsp;Qrels&nbsp;&ndash;&ndash;&ndash;
#     </p>
# </div>

# %% [markdown]
# The Relevance assessments (“qrels”) 2021 test set in not available so the 2020 test set has been used to perform it.

# %%
import requests
import pandas as pd

# %%
url_train = "https://trecpodcasts.github.io/resources/2020_train_qrels.list"
url_test ="https://trecpodcasts.github.io/resources/2020_test_qrels.list"

# %%
response = requests.get(url_train)
lines = response.text.split("\n")

data_qrel = []
for line in lines:
    if line:
        query, _, episode_uri, relevance = line.split("\t")
        data_qrel.append({"query": query, "episode_uri": episode_uri, "relevance": relevance})

qrel = pd.DataFrame(data_qrel)
qrel.shape
# Out:
# (609, 3)

# %%
qrel
# Out:
#     query                                    episode_uri relevance
# 0       1   spotify:episode:0E2nqCXMkS218SE72APmNr_240.0         2
# 1       1   spotify:episode:0E2nqCXMkS218SE72APmNr_300.0         2
# 2       1   spotify:episode:0E2nqCXMkS218SE72APmNr_360.0         2
# 3       1   spotify:episode:0Th494DvnO5dU8vTi3QHm2_120.0         1
# 4       1  spotify:episode:199bOiXL0l4YsRaSNDNXvP_1200.0         2
# ..    ...                                            ...       ...
# 604     8   spotify:episode:7MnlmF9PV3WUOPI8IjGd0y_720.0         0
# 605     8   spotify:episode:7MnlmF9PV3WUOPI8IjGd0y_780.0         0
# 606     8   spotify:episode:7wJUUYWcHm7YwEoCmTGFoD_240.0         1
# 607     8   spotify:episode:7wJUUYWcHm7YwEoCmTGFoD_300.0         1
# 608     8   spotify:episode:7yzpqVjoQqFh5k9W7esm29_360.0         0
#
# [609 rows x 3 columns]

# %%
# add Podcast Track 2020 test set QRels
url_test = "https://trecpodcasts.github.io/resources/2020_test_qrels.list"
response_test = requests.get(url_test)

lines_test = response_test.text.split("\n")
data_test = []
for line in lines_test:
    if line:
        query, _, episode_uri, relevance = line.split()
        data_test.append({"query": query, "episode_uri": episode_uri, "relevance": relevance})

qrel_test = pd.DataFrame(data_test)
qrel = qrel.append(qrel_test).reset_index(drop=True)
qrel.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 13
#      10         data_test.append({"query": query, "episode_uri": episode_uri, "relevance": relevance})
#      12 qrel_test = pd.DataFrame(data_test)
# ---> 13 qrel = qrel.append(qrel_test).reset_index(drop=True)
#      14 qrel.shape
#
# File ~/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
qrel
# Out:
#     query                                    episode_uri relevance
# 0       1   spotify:episode:0E2nqCXMkS218SE72APmNr_240.0         2
# 1       1   spotify:episode:0E2nqCXMkS218SE72APmNr_300.0         2
# 2       1   spotify:episode:0E2nqCXMkS218SE72APmNr_360.0         2
# 3       1   spotify:episode:0Th494DvnO5dU8vTi3QHm2_120.0         1
# 4       1  spotify:episode:199bOiXL0l4YsRaSNDNXvP_1200.0         2
# ..    ...                                            ...       ...
# 604     8   spotify:episode:7MnlmF9PV3WUOPI8IjGd0y_720.0         0
# 605     8   spotify:episode:7MnlmF9PV3WUOPI8IjGd0y_780.0         0
# 606     8   spotify:episode:7wJUUYWcHm7YwEoCmTGFoD_240.0         1
# 607     8   spotify:episode:7wJUUYWcHm7YwEoCmTGFoD_300.0         1
# 608     8   spotify:episode:7yzpqVjoQqFh5k9W7esm29_360.0         0
#
# [609 rows x 3 columns]

# %%
qrel['episode_uri'] = qrel['episode_uri'].apply(lambda uri: uri.split('_')[0])
qrel.head()
# Out:
#   query                             episode_uri relevance
# 0     1  spotify:episode:0E2nqCXMkS218SE72APmNr         2
# 1     1  spotify:episode:0E2nqCXMkS218SE72APmNr         2
# 2     1  spotify:episode:0E2nqCXMkS218SE72APmNr         2
# 3     1  spotify:episode:0Th494DvnO5dU8vTi3QHm2         1
# 4     1  spotify:episode:199bOiXL0l4YsRaSNDNXvP         2

# %%
qrel = qrel.groupby(['query', 'episode_uri']).max().reset_index()
qrel
# Out:
#     query                             episode_uri relevance
# 0       1  spotify:episode:0E2nqCXMkS218SE72APmNr         2
# 1       1  spotify:episode:0Th494DvnO5dU8vTi3QHm2         1
# 2       1  spotify:episode:199bOiXL0l4YsRaSNDNXvP         2
# 3       1  spotify:episode:1ZA1QTtylexrVt75xiprNH         2
# 4       1  spotify:episode:1o0HCHjNtRWdEWRTWJhzyC         0
# ..    ...                                     ...       ...
# 341     8  spotify:episode:7FC1oR9phxBJbtgp3u6jSJ         2
# 342     8  spotify:episode:7GYrSU135A75iYYcZ0WI0n         0
# 343     8  spotify:episode:7MnlmF9PV3WUOPI8IjGd0y         0
# 344     8  spotify:episode:7wJUUYWcHm7YwEoCmTGFoD         1
# 345     8  spotify:episode:7yzpqVjoQqFh5k9W7esm29         0
#
# [346 rows x 3 columns]

# %%
# Find all episodes present in qrels
in_qrels = data[data.episode_uri.isin(qrel.episode_uri.unique())]

# Check for NaN and empty string entries
null_or_empty = in_qrels[in_qrels.episode_description.isnull() | (in_qrels.episode_description == '')]

#converting empty show descript to blank list
# in_qrels['episode_description'] = in_qrels.episode_description.str.split().apply(lambda x: x if isinstance(x, list) else [])

# Check for one-word descriptions
# one_word_descr = in_qrels[in_qrels.episode_description.str.split().apply(len) == 1]

# Remove QRels with one-word episode descriptions
# qrel = qrel[~qrel.episode_uri.isin(one_word_descr.episode_uri)].reset_index(drop=True)

# %%
def one_word(x):
    try:
        len(x)
    except:
        0
in_qrels.episode_description.str.split().apply(lambda x: one_word(x))
# Out:
# 582       None
# 721       None
# 897       None
# 911       None
# 965       None
#           ...
# 104572    None
# 104673    None
# 104828    None
# 105033    None
# 105122    None
# Name: episode_description, Length: 344, dtype: object

# %%
# find episodes with non-empty descriptions in qrels
in_qrels = data[data['episode_uri'].isin(qrel['episode_uri'].unique()) & ~data['episode_description'].isna() & (data['episode_description'] != '')].reset_index(drop=True)

# find episodes with one-word descriptions
one_word_descr = list(in_qrels.index[in_qrels['episode_description'].apply(lambda row: bool(re.search(r'^\w+$', row)))])


# remove QRels with one word episode description
qrel = qrel[~qrel['episode_uri'].isin(in_qrels['episode_uri'][in_qrels.index.isin(one_word_descr)])].reset_index(drop=True)

qrel.shape
# Out:
# (346, 3)

# %%
import os
os.environ["JAVA_HOME"] = "/Library/Java/JavaVirtualMachines/jdk-20.jdk/Contents/Home"
import pyterrier as pt
import numpy as np
import pandas as pd
if not pt.started():
    pt.init()

# %%
data = pd.read_csv('metadata.tsv', sep = '\t')
data = data.astype(str)
data['docno'] = data.index
data =  data.loc[:10000]
data.head()
data.dtype

# %%
# !rm -rf ./pd_index
pd_indexer = pt.DFIndexer("./pd_index")
index = pd_indexer.index(data["episode_description"], data["docno"])
# Out:
# 15:07:52.119 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.123 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.128 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.134 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.141 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.144 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.154 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.169 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.179 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.198 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.208 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.221 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.233 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.241 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.256 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.269 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.305 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.308 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# 15:07:52.331 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.340 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.358 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.370 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.373 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.382 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.391 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.397 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.402 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.406 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.410 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.413 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.417 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.420 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.425 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.429 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.434 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.440 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.444 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.448 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.451 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.455 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.459 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.463 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.466 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.476 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.480 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.483 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.490 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.509 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.512 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.515 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.518 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.522 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.526 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.530 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.533 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:07:52.541 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
# ...
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# Traceback (most recent call last):
#   File "jnius/jnius_proxy.pxi", line 50, in jnius.PythonJavaClass.invoke
#   File "jnius/jnius_proxy.pxi", line 76, in jnius.PythonJavaClass._invoke
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 720, in next
#     lastdoc = self.convertFn(text, meta)
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pyterrier/index.py", line 628, in convertDoc
#     for column, value in meta_column[1].iteritems():
#   File "/Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/venv/lib/python3.9/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'iteritems'
# 15:08:03.384 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:08:03.388 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:08:03.392 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document
# 15:08:03.401 [main] WARN org.terrier.structures.indexing.Indexer - skipping null document

# %%
data["episode_description"].astype(str)
# Out:
# 0        On the first ever episode of Kream in your Kof...
# 1        See something, say something. It’s a mantra ma...
# 2        Today’s episode is a sit down Michael and Omar...
# 3        Join us as we take a look at all current Chief...
# 4        The modern morality tail of how to stay good f...
#                                ...
# 9996     Cicero uses a metaphor involving ship pilots a...
# 9997     Today we queue up a special podcast for #7 of ...
# 9998     Live video remains a core feature of the top s...
# 9999                                      gum.co/HydeWars
# 10000    In today’s episode I’m chatting with autism si...
# Name: episode_description, Length: 10001, dtype: object

# %%
index_file = pt.IndexFactory.of(index)
print(index_file.getCollectionStatistics())
# Out:
# 15:06:47.224 [main] WARN org.terrier.structures.BaseCompressingMetaIndex - File /Users/danielcrake/Desktop/Masters/Year 2/Information Retrieval /Assignment/pd_index/data.meta-0.fsomapfile containing reverse meta mapping for keydocno is missing. Reverse lookups for this key will be disabled
# Number of documents: 0
# Number of terms: 0
# Number of postings: 0
# Number of fields: 0
# Number of tokens: 0
# Field names: []
# Positions:   false
